# %%
from sklearn.datasets import make_regression
import pandas as pd

# %% [markdown]
# Вопрос 1. Создайте данные используя make_regression(n_samples=100, n_features=20, noise=10, random_state=42)
# Что можно сказать о полученных данных?
#
# 1. <font color='green'>Среднее признаков по модулю меньше единицы и стандартное отклонение около единицы (отличается не более, чем на 20%)</font>
# 2. <font color='red'>Есть корреляции больше .5 между разными признаками</font>
# 3. Для вычисления значений признаков требуется регуляризованная регрессия
# 4. Для лучшего предсказания признаки нужно отнормировать

# %%
X, y = make_regression(n_samples=100, n_features=20, noise=10, random_state=42)

# %%
X = pd.DataFrame(data=X)

# %%
X.describe()
# Out:
#                0           1           2           3           4           5   \
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean     0.066483   -0.090669    0.148793   -0.009252    0.066883    0.138678
# std      1.029991    0.977525    0.933608    0.895542    0.927696    0.923655
# min     -2.896255   -1.975467   -2.499406   -2.172670   -2.423879   -1.703382
# 25%     -0.534866   -0.857052   -0.356271   -0.640109   -0.496090   -0.552580
# 50%     -0.028445   -0.076344    0.178798   -0.016458    0.131194    0.145691
# 75%      0.757704    0.531959    0.721849    0.564199    0.493497    0.839220
# max      2.290943    2.439752    2.526932    2.122156    3.137749    3.078881
#
#                6           7           8           9           10          11  \
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean    -0.020263    0.135566    0.048246    0.021527   -0.067366    0.116212
# ...

# %%
corr = X.corr()
corr.style.background_gradient(cmap='bwr')
# Out:
# <style type="text/css">
# #T_cef08_row0_col0, #T_cef08_row1_col1, #T_cef08_row2_col2, #T_cef08_row3_col3, #T_cef08_row4_col4, #T_cef08_row5_col5, #T_cef08_row6_col6, #T_cef08_row7_col7, #T_cef08_row8_col8, #T_cef08_row9_col9, #T_cef08_row10_col10, #T_cef08_row11_col11, #T_cef08_row12_col12, #T_cef08_row13_col13, #T_cef08_row14_col14, #T_cef08_row15_col15, #T_cef08_row16_col16, #T_cef08_row17_col17, #T_cef08_row18_col18, #T_cef08_row19_col19 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_cef08_row0_col1, #T_cef08_row6_col4, #T_cef08_row7_col9, #T_cef08_row11_col13, #T_cef08_row12_col15, #T_cef08_row18_col16, #T_cef08_row19_col1 {
#   background-color: #3636ff;
#   color: #f1f1f1;
# }
# #T_cef08_row0_col2, #T_cef08_row8_col2 {
#   background-color: #1c1cff;
#   color: #f1f1f1;
# }
# #T_cef08_row0_col3, #T_cef08_row3_col6, #T_cef08_row4_col8, #T_cef08_row16_col13 {
#   background-color: #7676ff;
#   color: #f1f1f1;
# }
# ...

# %% [markdown]
# Вопрос 2. Используя sklearn.linear_model постройте LinearRegression, Ridge(random_state=1), Lasso на дефолтных параметрах и ненормированных признаках. Для оценки регрессии используем R2 из функции score модели.
#
# Ответьте на вопросы 1-3.
#
# Теперь отнормируйте признаки. Постройте опять 3 регрессии.
#
# Ответьте на вопросы 4-6.
#
# Вопрос 7 относится ко всем построенным в вопросе регрессиям.
#
# 1. По score (R2) Ridge лучше всего
# 2. <font color='green'>По score (R2) LinearRegression лучше всего</font>
# 3. По score (R2) Lasso лучше всего
# 4. <font color='green'>По score (R2) Ridge лучше всего</font>
# 5. По score (R2) LinearRegression лучше всего
# 6. По score (R2) Lasso лучше всего
# 7. Из всех построенных регрессий в вопросе, Ridge лучше всего
